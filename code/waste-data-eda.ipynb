# %%
import pandas as pd

# %% [markdown]
# ## Global Data

# %% [markdown]
# ### World Bank
#
# - Source: https://datacatalog.worldbank.org/dataset/what-waste-global-database
#
# - Global data on 336 cities. The metrics included cover all steps from the waste management value chain, including waste generation, composition, collection, and disposal, as well as information on user fees and financing, the informal sector, administrative structures, public communication, and legal information.

# %%
world_bank_city_data = pd.read_csv('../data/worldbank-city-level-data.csv')
world_bank_city_data.sample(5) #  a lot of nans
# Out:
#     iso3c region_id        country_name income_id  city_name  \
# 298   RUS       ECS  Russian Federation       UMC   Kemerovo
# 275   PAK       SAS            Pakistan       LMC     Lahore
# 70    CRI       LCN          Costa Rica       UMC  San Jos̩
# 326   TUN       MEA             Tunisia       LMC       Sfax
# 74    CYP       ECS              Cyprus       HIC    Nicosia
#
#     additional_data_annual_budget_for_waste_management_year  \
# 298                                                NaN
# 275                                                NaN
# 70                                                 NaN
# 326                                                NaN
# 74                                                 NaN
#
#     additional_data_annual_solid_waste_budget_year  \
# 298                                            NaN
# 275                                            NaN
# 70                                             NaN
# 326                                            NaN
# 74                                             NaN
#
#      additional_data_annual_swm_budget_2017_year  \
# 298                                          NaN
# 275                                          NaN
# 70                                           NaN
# 326                                          NaN
# 74                                           NaN
#
#      additional_data_annual_swm_budget_year  \
# 298                                     NaN
# 275                                     NaN
# 70                                      NaN
# 326                                     NaN
# 74                                      NaN
#
#      additional_data_annual_waste_budget_year  ...  \
# 298                                       NaN  ...
# 275                                       NaN  ...
# 70                                        NaN  ...
# 326                                       NaN  ...
# 74                                        NaN  ...
#
#      waste_treatment_compost_percent  \
# 298                              NaN
# 275                              NaN
# 70                               NaN
# 326                              NaN
# 74                              2.87
#
#      waste_treatment_controlled_landfill_percent  \
# 298                                          NaN
# 275                                        61.53
# 70                                           NaN
# 326                                          NaN
# 74                                           NaN
#
#     waste_treatment_incineration_percent  \
# 298                                  NaN
# 275                                 6.15
# 70                                   NaN
# 326                                  NaN
# 74                                   NaN
#
#     waste_treatment_landfill_unspecified_percent  \
# 298                                          NaN
# 275                                          NaN
# 70                                           NaN
# 326                                          NaN
# 74                                         87.23
#
#     waste_treatment_open_dump_percent  waste_treatment_other_percent  \
# 298                              98.1                            NaN
# 275                               NaN                            NaN
# 70                                NaN                           0.38
# 326                               NaN                            NaN
# 74                                NaN                            NaN
#
#      waste_treatment_recycling_percent  \
# 298                               1.90
# 275                                NaN
# 70                                5.20
# 326                               2.00
# 74                                9.89
#
#      waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 298                                                NaN
# 275                                              32.31
# 70                                               94.42
# 326                                              98.00
# 74                                                 NaN
#
#     waste_treatment_unaccounted_for_percent  \
# 298                                     NaN
# 275                                    0.01
# 70                                      NaN
# 326                                     NaN
# 74                                     0.01
#
#     waste_treatment_waterways_marine_percent
# 298                                      NaN
# 275                                      NaN
# 70                                       NaN
# 326                                      NaN
# 74                                       NaN
#
# [5 rows x 113 columns]

# %%
world_bank_city_data.shape
# Out:
# (367, 113)

# %%
world_bank_city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Columns: 113 entries, iso3c to waste_treatment_waterways_marine_percent
# dtypes: float64(70), object(43)
# memory usage: 324.1+ KB

# %%
city_data.describe()
# Out:
#        additional_data_annual_swm_budget_2017_year  \
# count                                          1.0
# mean                                     1030281.0
# std                                            NaN
# min                                      1030281.0
# 25%                                      1030281.0
# 50%                                      1030281.0
# 75%                                      1030281.0
# max                                      1030281.0
#
#        additional_data_annual_swm_budget_year  \
# count                            2.000000e+00
# mean                             2.599229e+06
# std                              3.506159e+06
# min                              1.200000e+05
# 25%                              1.359614e+06
# 50%                              2.599229e+06
# 75%                              3.838844e+06
# max                              5.078458e+06
#
#        additional_data_annual_waste_budget_year  \
# count                                       1.0
# mean                                  4035882.0
# std                                         NaN
# min                                   4035882.0
# 25%                                   4035882.0
# 50%                                   4035882.0
# 75%                                   4035882.0
# max                                   4035882.0
#
#        additional_data_collection_ton  \
# count                            1.00
# mean                             0.73
# std                               NaN
# min                              0.73
# 25%                              0.73
# 50%                              0.73
# 75%                              0.73
# max                              0.73
#
#        additional_data_number_of_scavengers_on_dumpsites_number  \
# count                                                1.0
# mean                                               200.0
# std                                                  NaN
# min                                                200.0
# 25%                                                200.0
# 50%                                                200.0
# 75%                                                200.0
# max                                                200.0
#
#        additional_data_total_annual_costs_to_collect_and_dispose_of_city_s_waste_year  \
# count                                                1.0
# mean                                           5900000.0
# std                                                  NaN
# min                                            5900000.0
# 25%                                            5900000.0
# 50%                                            5900000.0
# 75%                                            5900000.0
# max                                            5900000.0
#
#        additional_data_total_swm_expenditures_year  \
# count                                          1.0
# mean                                       36424.0
# std                                            NaN
# min                                        36424.0
# 25%                                        36424.0
# 50%                                        36424.0
# 75%                                        36424.0
# max                                        36424.0
#
#        additional_data_total_waste_management_budget_year  \
# count                                                1.0
# mean                                            475000.0
# std                                                  NaN
# min                                             475000.0
# 25%                                             475000.0
# 50%                                             475000.0
# 75%                                             475000.0
# max                                             475000.0
#
#        composition_food_organic_waste_percent  composition_glass_percent  ...  \
# count                              291.000000                 269.000000  ...
# mean                                45.424727                   4.058437  ...
# std                                 18.321482                   3.959363  ...
# min                                  0.930000                   0.000000  ...
# 25%                                 34.200000                   1.500000  ...
# 50%                                 47.900000                   3.000000  ...
# 75%                                 57.350000                   5.000000  ...
# max                                 88.800000                  32.580000  ...
#
#        waste_treatment_compost_percent  \
# count                        67.000000
# mean                         19.352687
# std                          20.207610
# min                           0.000000
# 25%                           2.785000
# 50%                          14.000000
# 75%                          28.500000
# max                          82.000000
#
#        waste_treatment_controlled_landfill_percent  \
# count                                    60.000000
# mean                                     46.004000
# std                                      30.798648
# min                                       0.000000
# 25%                                      20.000000
# 50%                                      48.700000
# 75%                                      67.025000
# max                                     100.000000
#
#        waste_treatment_incineration_percent  \
# count                             29.000000
# mean                              42.091724
# std                               29.848297
# min                                0.230000
# 25%                               10.000000
# 50%                               41.020000
# 75%                               71.100000
# max                               90.330000
#
#        waste_treatment_landfill_unspecified_percent  \
# count                                     16.000000
# mean                                      57.646875
# std                                       35.336363
# min                                        9.000000
# 25%                                       23.750000
# 50%                                       70.050000
# 75%                                       87.707500
# max                                      100.000000
#
#        waste_treatment_open_dump_percent  waste_treatment_other_percent  \
# count                         100.000000                      48.000000
# mean                           66.203200                      21.750771
# std                            33.515912                      21.412265
# min                             0.000000                       0.000000
# 25%                            40.475000                       5.750000
# 50%                            74.500000                      14.710000
# 75%                           100.000000                      36.182500
# max                           100.000000                      87.560000
#
#        waste_treatment_recycling_percent  \
# count                         128.000000
# mean                           15.599063
# std                            15.488925
# min                             0.000000
# 25%                             4.807500
# 50%                            10.000000
# 75%                            21.000000
# max                            72.000000
#
#        waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# count                                          56.000000
# mean                                           66.106607
# std                                            31.469398
# min                                             0.000000
# 25%                                            42.025000
# 50%                                            78.050000
# 75%                                            90.500000
# max                                           100.000000
#
#        waste_treatment_unaccounted_for_percent  \
# count                               121.000000
# mean                                 32.496331
# std                                  30.609756
# min                                   0.000000
# 25%                                   5.000000
# 50%                                  25.500000
# 75%                                  56.000000
# max                                  99.850000
#
#        waste_treatment_waterways_marine_percent
# count                                  4.000000
# mean                                  20.775000
# std                                   14.125715
# min                                    5.000000
# 25%                                   11.000000
# 50%                                   21.550000
# 75%                                   31.325000
# max                                   35.000000
#
# [8 rows x 70 columns]

# %% [markdown]
# ### OECD (Organisation for Economic Co-operation and Development)

# %% [markdown]
# #### Municipal Waste Generation and Treatment by Country and Year
#
# - Source: https://stats.oecd.org/Index.aspx?DataSetCode=MUNW

# %%
oecd_municipal_waste = pd.read_csv('../data/oecd-waste-municipal.csv')
oecd_municipal_waste.head(5)
# Out:
#    COU    Country        VAR                   Variable   YEA  Year Unit Code  \
# 0  AUS  Australia  MUNICIPAL  Municipal waste generated  1992  1992     TONNE
# 1  AUS  Australia  MUNICIPAL  Municipal waste generated  2000  2000     TONNE
# 2  AUS  Australia  MUNICIPAL  Municipal waste generated  2007  2007     TONNE
# 3  AUS  Australia  MUNICIPAL  Municipal waste generated  2008  2008     TONNE
# 4  AUS  Australia  MUNICIPAL  Municipal waste generated  2009  2009     TONNE
#
#      Unit  PowerCode Code  PowerCode Reference Period Code Reference Period  \
# 0  Tonnes               3  Thousands                   NaN              NaN
# 1  Tonnes               3  Thousands                   NaN              NaN
# 2  Tonnes               3  Thousands                   NaN              NaN
# 3  Tonnes               3  Thousands                   NaN              NaN
# 4  Tonnes               3  Thousands                   NaN              NaN
#
#      Value Flag Codes            Flags
# 0  12000.0          E  Estimated value
# 1  13200.0          E  Estimated value
# 2  12873.0        NaN              NaN
# 3  13096.5        NaN              NaN
# 4  13320.0        NaN              NaN

# %%
oecd_municipal_waste.shape
# Out:
# (20779, 15)

# %%
oecd_municipal_waste.Country.unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Slovak Republic', 'Spain', 'Sweden', 'Switzerland',
#        'Turkey', 'United Kingdom', 'United States', 'Brazil', 'Chile',
#        "China (People's Republic of)", 'Estonia', 'Indonesia', 'Israel',
#        'Russia', 'Slovenia', 'OECD - Total', 'OECD - Europe', 'Colombia',
#        'Latvia', 'Costa Rica', 'India', 'Lithuania', 'OECD Asia Oceania',
#        'OECD America'], dtype=object)

# %% [markdown]
# #### Waste Generation by Sector.
#
# - Gives the waste generated by each industry and in which country.
# - Source: https://stats.oecd.org/Index.aspx?DataSetCode=MUNW

# %%
oecd_sector_waste = pd.read_csv('../data/oecd-waste-sector.csv')
oecd_sector_waste.head(5)
# Out:
#    COU    Country   ISIC                                           Variable  \
# 0  AUS  Australia  10-33                    Manufacturing industries: Total
# 1  AUS  Australia  10-33                    Manufacturing industries: Total
# 2  AUS  Australia  10-12  Manufacture of food products; beverages and to...
# 3  AUS  Australia  13-15  Manufacture of textiles, wearing apparel, leat...
# 4  AUS  Australia     16  Manufacture of wood and of products of wood an...
#
#     YEA  Year Unit Code    Unit  PowerCode Code  PowerCode  \
# 0  2009  2009     TONNE  Tonnes               3  Thousands
# 1  2011  2011     TONNE  Tonnes               3  Thousands
# 2  2011  2011     TONNE  Tonnes               3  Thousands
# 3  2011  2011     TONNE  Tonnes               3  Thousands
# 4  2011  2011     TONNE  Tonnes               3  Thousands
#
#    Reference Period Code  Reference Period    Value Flag Codes Flags
# 0                    NaN               NaN  13116.0        NaN   NaN
# 1                    NaN               NaN   3858.2        NaN   NaN
# 2                    NaN               NaN    920.0        NaN   NaN
# 3                    NaN               NaN    171.9        NaN   NaN
# 4                    NaN               NaN    164.3        NaN   NaN

# %% [markdown]
# ---
#
# ## National Data

# %% [markdown]
# ### EIA energy consumption

# %%
us_region_energy_usage = pd.read_csv('../data/eia-residential-energy-consumption.csv',index_col=0)
us_region_energy_usage.head(10)
# Out:
#                            Total U.S.2 (Number of housing units (million))  \
# All homes                                                            118.2
# Census region and division
# Northeast                                                               21
# New England                                                            5.6
# Middle Atlantic                                                       15.4
# Midwest                                                               26.4
# East North Central                                                    18.1
# West North Central                                                     8.3
# South                                                                 44.4
# South Atlantic                                                        23.5
#
#                            Total Average energy expenditures \n(dollars per household using the end use)  \
# All homes                                                               1,856
# Census region and division
# Northeast                                                               2,269
# New England                                                             2,541
# Middle Atlantic                                                         2,169
# Midwest                                                                 1,760
# East North Central                                                      1,762
# West North Central                                                      1,757
# South                                                                   1,917
# South Atlantic                                                          1,963
#
#                            Space heating3 Water heating Air condi-tioning  \
# All homes                             543           296               265
# Census region and division
# Northeast                             850           335               174
# New England                         1,046           379               127
# Middle Atlantic                       779           318               188
# Midwest                               604           246               148
# East North Central                    612           247               140
# West North Central                    587           243               166
# South                                 465           323               392
# South Atlantic                        488           344               386
#
#                            Refrig-erators Other4
# All homes                             103    714
# Census region and division
# Northeast                             120    834
# New England                           124    926
# Middle Atlantic                       118    800
# Midwest                                99    681
# East North Central                    101    676
# West North Central                     96    691
# South                                  93    694
# South Atlantic                         95    714

# %%
us_region_energy_usage.iloc[17:25]
# Out:
#                                               Total U.S.2 (Number of housing units (million))  \
# Census urban/rural classification5
# Urban                                                                                    94.7
# Urbanized area                                                                           82.2
# Urban cluster                                                                            12.5
# Rural                                                                                    23.5
# Metropolitan or micropolitan statistical area
# In metropolitan statistical area                                                         98.5
# In micropolitan statistical area                                                         12.3
#
#                                               Total Average energy expenditures \n(dollars per household using the end use)  \
# Census urban/rural classification5
# Urban                                                                                      1,773
# Urbanized area                                                                             1,782
# Urban cluster                                                                              1,710
# Rural                                                                                      2,190
# Metropolitan or micropolitan statistical area
# In metropolitan statistical area                                                           1,840
# In micropolitan statistical area                                                           1,861
#
#                                               Space heating3 Water heating  \
# Census urban/rural classification5
# Urban                                                    495           274
# Urbanized area                                           488           272
# Urban cluster                                            540           286
# Rural                                                    737           382
# Metropolitan or micropolitan statistical area
# In metropolitan statistical area                         520           287
# In micropolitan statistical area                         626           325
#
#                                               Air condi-tioning  \
# Census urban/rural classification5
# Urban                                                       269
# Urbanized area                                              279
# Urban cluster                                               202
# Rural                                                       253
# Metropolitan or micropolitan statistical area
# In metropolitan statistical area                            274
# In micropolitan statistical area                            195
#
#                                               Refrig-erators Other4
# Census urban/rural classification5
# Urban                                                    102    694
# Urbanized area                                           104    705
# Urban cluster                                             92    625
# Rural                                                    105    791
# Metropolitan or micropolitan statistical area
# In metropolitan statistical area                         105    723
# In micropolitan statistical area                          91    657

# %% [markdown]
# ### [todo]  BLS demographic information, Census data
#
# ...

# %% [markdown]
# ---
#
# ## State / Regional Data

# %% [markdown]
# ### Cal Recycle

# %%
alameda_waste = pd.read_csv('../data/calrecycle-alameda-waste-material.csv')
alameda_waste.head(5)
# Out:
#   Material Category                  Material Type       Jurisdiction(s)  \
# 0             Paper  Uncoated Corrugated Cardboard  Alameda (Countywide)
# 1             Paper                     Paper Bags  Alameda (Countywide)
# 2             Paper                      Newspaper  Alameda (Countywide)
# 3             Paper             White Ledger Paper  Alameda (Countywide)
# 4             Paper             Other Office Paper  Alameda (Countywide)
#
#    Single Family Tons Regional Single Family Composition  Multi Family Tons  \
# 0                1917                               0.7%               4231
# 1                 898                               0.3%                625
# 2                2078                               0.7%               5506
# 3                 531                               0.2%                627
# 4                1368                               0.5%                698
#
#   Statewide Multi Family Composition  Total Residential Tons  \
# 0                               3.6%                    6147
# 1                               0.5%                    1523
# 2                               4.6%                    7583
# 3                               0.5%                    1158
# 4                               0.6%                    2067
#
#   Total Residential Composition  Unnamed: 9
# 0                          1.5%         NaN
# 1                          0.4%         NaN
# 2                          1.9%         NaN
# 3                          0.3%         NaN
# 4                          0.5%         NaN
